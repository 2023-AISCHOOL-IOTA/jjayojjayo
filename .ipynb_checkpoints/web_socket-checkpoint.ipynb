# %%
import exam1_2
import exam2_3
import pymysql
import atexit

from flask import Flask, request
from flask import jsonify, render_template
from flask_cors import CORS

from flask_socketio import SocketIO

from gevent import pywsgi
from geventwebsocket.handler import WebSocketHandler
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %% [markdown]
# # from flask_socketio import SocketIO

# %%
app = Flask(__name__)
CORS(app)
app.config['SECRET_KEY'] = '1234'
socketio = SocketIO(app, cors_allowed_origins="*")

@app.route('/')
def index():
    return render_template('main.html')

# 클라이언트로부터 웹소켓 메시지를 받는 이벤트 핸들러
@socketio.on('message')
def handle_message(client_message):
    sender_id = request.sid
    print('Received message:', client_message, 'from', sender_id)
    result = run_ai_model(client_message)     # AI 모델을 사용하여 결과 생성
    #socketio.broadcast.emit('response', result)     # 결과를 클라이언트에게 보냅니다.
    print("받은 메세지 : ", result)
    socketio.emit('response', {'message': result, 'sender_id': sender_id})

def run_ai_model(client_message):
    # AI 모델의 예측을 수행하고 결과를 반환합니다.
    if exam1_1.sentence_predict(client_message) == 0:
        result = exam2_1.sentence_predict(client_message)
    elif exam1_1.sentence_predict(client_message) == 2:
        result = "그런 말은 하면 안 돼요"
    else :
        result = client_message
    return result
#172.24.218.228:5020
if __name__ == '__main__':
    socketio.run(app, host='192.168.21.72', port=5020)

# %% [markdown]
# 페이지 주소로는 내 컴퓨터 내에서 몇번이고 페이지를 열 수 있음. 나와 상대를 구분해야한다.
#
# 닉네임값만 입력할 수 있도록(조건을 달아줘야 한다.) ->
#
# 1. 여러 페이지에서도 한 페이지에서 쓴 글 같이 보일 수 있도록 하기
# 2. 가나/나 다라/너

# %% [markdown]
# # from flask_sockets import Sockets

# %%
# app = Flask(__name__)
# CORS(app)
# sockets = Sockets(app)

# @app.route('/')
# def index():
#     return render_template('main.html')


# # 웹소켓 클라이언트를 추적하는 set
# connected_clients = set()

# @sockets.route('/echo')
# def echo_socket(ws):
#     # 연결된 클라이언트를 set에 추가합니다.
#     connected_clients.add(ws)
#     try:
#         while not ws.closed:
#             client_message = ws.receive()
#             if client_message:
#                 print('Received message:', client_message)
#                 # AI 모델을 사용하여 결과 생성 (예: exam1.sentence_predict, exam2.sentence_predict)
#                 result = run_ai_model(client_message)  # 변수명 변경
#                 # 결과를 모든 연결된 클라이언트에게 보냅니다.
#                 for client in connected_clients:
#                     client.send(result)
#                     print('Sent message to:', client)
#     finally:
#         # 클라이언트 연결이 끊어지면 연결 목록에서 제거합니다.
#         connected_clients.remove(ws)

# def run_ai_model(client_message):
#     # 여기에서 AI 모델의 예측을 수행하고 결과를 반환합니다.
#     if exam1.sentence_predict(client_message) == 0:
#         result = exam2.sentence_predict(client_message)
#     else:
#         result = client_message
#     return result


# if __name__ == '__main__':
#     server = pywsgi.WSGIServer(('127.0.0.1', 5018), app, handler_class=WebSocketHandler)
#     try:
#         server.serve_forever()
#     except KeyboardInterrupt:
#         print("서버가 사용자에 의해 중단되었습니다.")

# %% [markdown]
# # 겸+ Flask + bootstrap

# %%
app = Flask(__name__)
CORS(app) # 그냥 보안상 존재함
app.config['SECRET_KEY'] = '1234'
socketio = SocketIO(app, cors_allowed_origins="*")

# MySQL 연결 설정
app.config["MYSQL_HOST"] = "project-db-stu3.smhrd.com"  # MySQL 호스트 주소
app.config["MYSQL_USER"] = "Insa4_IOTA_final_2"  # MySQL 사용자 이름
app.config["MYSQL_PASSWORD"] = "aischool2"  # MySQL 비밀번호
app.config["MYSQL_DB"] = "Insa4_IOTA_final_2"  # 사용할 데이터베이스 이름
app.config["MYSQL_PORT"] = 3307  # MySQL 포트 번호

# MySQL 연결
mysql_conn = pymysql.connect(
    host=app.config["MYSQL_HOST"],
    user=app.config["MYSQL_USER"],
    password=app.config["MYSQL_PASSWORD"],
    database=app.config["MYSQL_DB"],
    port=app.config["MYSQL_PORT"],
    cursorclass=pymysql.cursors.DictCursor
    )

#전역변수로 사용할 original_sentence, translate_sentence 선언
global original_sentence
global translated_sentence


@app.route('/')
def index():
    return render_template('chat.html')


# 클라이언트로부터 웹소켓 메시지를 받는 이벤트 핸들러
@socketio.on('message')
def handle_message(client_message):
    sender_id = request.sid
    print('Received message:', client_message, 'from', sender_id)
    result = run_ai_model(client_message)     # AI 모델을 사용하여 결과 생성
    #socketio.broadcast.emit('response', result)     # 결과를 클라이언트에게 보냅니다.
    print("받은 메세지 : ", result)
    socketio.emit('response', {'message': result, 'sender_id': sender_id})
    global original_sentence
    original_sentence = client_message

def run_ai_model(client_message):
    # AI 모델의 예측을 수행하고 결과를 반환합니다.
    if exam1_2.sentence_predict(client_message) == 0:
        result = exam2_3.sentence_predict(client_message)
    elif exam1_2.sentence_predict(client_message) == 2:
        result = "그런 말은 하면 안 돼요"
    else :
        result = client_message
    global translated_sentence
    translated_sentence = result
    return result

#싫어요 제출하면 받아서 db에 저장하는 함수
@app.route('/submit_dislike', methods=['POST'])
def submit_dislike():
    cursor=mysql_conn.cursor()
    gender = request.form.get('gender')
    age = request.form.get('age')
    dislike_reason = request.form.get('dislike_reason')
    reason_etc = request.form.get('reason_etc')
    global original_sentence
    global translated_sentence
    
    # MySQL 데이터베이스에 연결
    try:
        # SQL 쿼리 실행
        if dislike_reason == 'reason3':
            sql = "INSERT INTO bad_translate_reason (gender, age, reason, originalSentence, translateSentence) VALUES (%s, %s, %s, %s, %s)"
            cursor.execute(sql, (gender, age, reason_etc, original_sentence, translated_sentence))             
        else:
            sql = "INSERT INTO bad_translate_reason (gender, age, reason, originalSentence, translateSentence) VALUES (%s, %s, %s, %s, %s)"
            cursor.execute(sql, (gender, age, dislike_reason, original_sentence, translated_sentence))
               
        # 변경사항을 커밋
        mysql_conn.commit()
        # 응답 데이터를 생성
        response_data = {'result': '데이터베이스에 저장 완료'}

    except Exception as e:
        # 오류 발생 시 롤백
        mysql_conn.rollback()
        response_data = {'error': str(e)}
    finally:
        # 연결 종료
        cursor.close()
        print(response_data)

    return jsonify(response_data)

#관리자 페이지에 데이터 불러오기
@app.route("/administrator")
def administrator():
    # 커서 객체 생성
    cursor = mysql_conn.cursor()

    # 데이터베이스에서 데이터 검색
    query = "SELECT * FROM bad_translate_reason" 
    cursor.execute(query)

    data = cursor.fetchall()
    cursor.close()

    # admin.html에 데이터 전달
    return render_template("admin.html", data=data)

# Flask 앱 종료 시 MySQL 연결 닫기
def close_mysql_connection():
    if mysql_conn:
        mysql_conn.close()
        print("MySQL connection closed.")

# Flask 앱 종료 시 close_mysql_connection 함수 호출
atexit.register(close_mysql_connection)

if __name__ == '__main__':
    socketio.run(app, host='192.168.21.72', port=5020)
# Out:
# Received message: 안녕? from zIUvjYZZXBSUOY_-AAAD
# 받은 메세지 :  안녕?
# Received message: 그래 안녕 from GE9cOXBaZ-AmOLnDAAAF
# 받은 메세지 :  그래 안녕
# Received message: 흑형들이 하니까 주작티 안나고 유쾌하네 from zIUvjYZZXBSUOY_-AAAD
# 받은 메세지 :  흑인들이 하니까 조작티 안나고 유쾌하네
# Received message: 야 너는 느금마가 낙태 실패해서 그렇게 태어났냐? from GE9cOXBaZ-AmOLnDAAAF
# 받은 메세지 :  그런 말은 하면 안 돼요
# Received message: 안녕? from b-TVTysR8V-chbTaAAAH
# 받은 메세지 :  안녕?
# Received message: 안녕? from 3u6ImksveRp0Vv8cAAAL
# 받은 메세지 :  안녕?
# Received message: 그래 안녕 from mXO-sMiV7eFPPZwQAAAN
# 받은 메세지 :  그래 안녕
# Received message: 흑형들이 하니까 주작티 안나고 유쾌하네 from 3u6ImksveRp0Vv8cAAAL
# 받은 메세지 :  흑인들이 하니까 조작티 안나고 유쾌하네
# Received message: 야 너는 느금마가 낙태 실패해서 그렇게 태어났냐? from mXO-sMiV7eFPPZwQAAAN
# 받은 메세지 :  그런 말은 하면 안 돼요
# Traceback (most recent call last):
#   File "C:\Users\kbh27\anaconda3\Lib\site-packages\gevent\_ffi\loop.py", line 270, in python_check_callback
#     def python_check_callback(self, watcher_ptr): # pylint:disable=unused-argument
#
# KeyboardInterrupt
# 2023-11-29T01:25:55Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 120
#     117 atexit.register(close_mysql_connection)
#     119 if __name__ == '__main__':
# --> 120     socketio.run(app, host='192.168.21.72', port=5020)
#
# File ~\anaconda3\Lib\site-packages\flask_socketio\__init__.py:718, in SocketIO.run(self, app, host, port, **kwargs)
#     716     run_with_reloader(run_server, **reloader_options)
#     717 else:
# --> 718     self.wsgi_server.serve_forever()
#
# File ~\anaconda3\Lib\site-packages\gevent\baseserver.py:400, in BaseServer.serve_forever(self, stop_timeout)
#     398     self.start()
#     399 try:
# --> 400     self._stop_event.wait()
#     401 finally:
#     402     Greenlet.spawn(self.stop, timeout=stop_timeout).join()
#
# File src\\gevent\\event.py:163, in gevent._gevent_cevent.Event.wait()
#
# File src\\gevent\\_abstract_linkable.py:521, in gevent._gevent_c_abstract_linkable.AbstractLinkable._wait()
#
# File src\\gevent\\_abstract_linkable.py:487, in gevent._gevent_c_abstract_linkable.AbstractLinkable._wait_core()
#
# File src\\gevent\\_abstract_linkable.py:490, in gevent._gevent_c_abstract_linkable.AbstractLinkable._wait_core()
#
# File src\\gevent\\_abstract_linkable.py:442, in gevent._gevent_c_abstract_linkable.AbstractLinkable._AbstractLinkable__wait_to_be_notified()
#
# File src\\gevent\\_abstract_linkable.py:451, in gevent._gevent_c_abstract_linkable.AbstractLinkable._switch_to_hub()
#
# File src\\gevent\\_greenlet_primitives.py:61, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src\\gevent\\_greenlet_primitives.py:65, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src\\gevent\\_gevent_c_greenlet_primitives.pxd:35, in gevent._gevent_c_greenlet_primitives._greenlet_switch()
#
# File ~\anaconda3\Lib\site-packages\gevent\_ffi\loop.py:270, in AbstractCallbacks.python_check_callback(self, watcher_ptr)
#     267     watcher.stop()
#     269 if not PYPY:
# --> 270     def python_check_callback(self, watcher_ptr): # pylint:disable=unused-argument
#     271         # If we have the onerror callback, this is a no-op; all the real
#     272         # work to rethrow the exception is done by the onerror callback
#     273
#     274         # NOTE: Unlike the rest of the functions, this is called with a pointer
#     275         # to the C level structure, *not* a pointer to the void* that represents a
#     276         # <cdata> for the Python Watcher object.
#     277         pass
#     278 else: # PyPy
#     279     # On PyPy, we need the function to have some sort of body, otherwise
#     280     # the signal exceptions don't always get caught, *especially* with
#    (...)
#     284     # test_socket's test_sendall_interrupted can hang.
#     285     # See https://github.com/gevent/gevent/issues/1112
#
# KeyboardInterrupt:
